# %%
import os
import pandas as pd
import numpy as np
import folium

# %%
import os

def count_files_in_folder(folder_path):
    if not os.path.isdir(folder_path):
        print("Invalid folder path.")
        return
    
    file_count = 0
    for _, _, files in os.walk(folder_path):
        file_count += len(files)
    
    print(f"Number of files in {folder_path}: {file_count}")

# Example usage:
folder_path = '/Users/gayathri/Desktop/Format_0'
count_files_in_folder(folder_path)
# Out:
# Number of files in /Users/gayathri/Desktop/Format_0: 119

# %%
#This is to generate sub_bart_label files for each domain
def process_csv(csv_file, output_folder):
    data = pd.read_csv(csv_file)
    grouped = data.groupby('bart_label')
    for bart_label, group in grouped:
        filename = os.path.join(output_folder, f'{os.path.splitext(os.path.basename(csv_file))[0]}_{bart_label.lower()}.csv')  
        group.to_csv(filename, index=False)

folder_path = '/Users/gayathri/Desktop/Format_0'
output_folder = '/Users/gayathri/Desktop/Format_1'
os.makedirs(output_folder, exist_ok=True)

# Iterate through each file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".csv"):
        csv_file = os.path.join(folder_path, file_name)
        process_csv(csv_file, output_folder)

# %%
###This is to put all the files of same domain to one folder###
import os
import shutil

def organize_csv_files(folder_path):
    # Create a dictionary to store folder paths for each prefix
    folder_paths = {}
    
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".csv"):
            prefix = file_name.split('_')[0]
            
            if prefix not in folder_paths:
                folder_paths[prefix] = os.path.join(folder_path, prefix)
                folder_path_suffix = 0
                while os.path.exists(folder_paths[prefix]):
                    folder_path_suffix += 1
                    folder_paths[prefix] = os.path.join(folder_path, f"{prefix}_{folder_path_suffix}")
                os.makedirs(folder_paths[prefix], exist_ok=True)
            
            src_file = os.path.join(folder_path, file_name)
            dst_file = os.path.join(folder_paths[prefix], file_name)
            shutil.move(src_file, dst_file)

folder_path = '/Users/gayathri/Desktop/Format_1'

organize_csv_files(folder_path)

# %%
##This step also acts like a verification
## 1. To add all data files accordingly to each sub-domain folder, this also ensures that there are sub-folders existing for each of the domains.

import os
import shutil

def copy_files_to_matching_subfolder(folder_1, folder_2):
    for filename in os.listdir(folder_1):
        if filename.endswith(".csv"):
            csv_file_path = os.path.join(folder_1, filename)
            subfolder_name = os.path.splitext(filename)[0]  
            subfolder_path = os.path.join(folder_2, subfolder_name)

            # Check if the subfolder exists in folder_2
            if os.path.isdir(subfolder_path):
                new_filename = os.path.splitext(filename)[0] + "_all.csv"
                destination_path = os.path.join(subfolder_path, new_filename)
                shutil.copyfile(csv_file_path, destination_path)
                print(f"File {filename} copied to {destination_path}")
            else:
                print(f"No matching subfolder found for {filename}")

folder_1 = "/Users/gayathri/Desktop/Format_0"
folder_2 = "/Users/gayathri/Desktop/Format_1"
copy_files_to_matching_subfolder(folder_1, folder_2)
# Out:
# File 920thejersey.csv copied to /Users/gayathri/Desktop/Format_1/920thejersey/920thejersey_all.csv
# File thepakistaninewspaper.csv copied to /Users/gayathri/Desktop/Format_1/thepakistaninewspaper/thepakistaninewspaper_all.csv
# File mcccvoice.csv copied to /Users/gayathri/Desktop/Format_1/mcccvoice/mcccvoice_all.csv
# File stocktonargo.csv copied to /Users/gayathri/Desktop/Format_1/stocktonargo/stocktonargo_all.csv
# File koreadailyus.csv copied to /Users/gayathri/Desktop/Format_1/koreadailyus/koreadailyus_all.csv
# No matching subfolder found for 987thecoast.csv
# File wurdradio.csv copied to /Users/gayathri/Desktop/Format_1/wurdradio/wurdradio_all.csv
# File wqxr.csv copied to /Users/gayathri/Desktop/Format_1/wqxr/wqxr_all.csv
# File civicstory.csv copied to /Users/gayathri/Desktop/Format_1/civicstory/civicstory_all.csv
# File jerseyvoices.csv copied to /Users/gayathri/Desktop/Format_1/jerseyvoices/jerseyvoices_all.csv
# File wpst.csv copied to /Users/gayathri/Desktop/Format_1/wpst/wpst_all.csv
# File hobokenhorse.csv copied to /Users/gayathri/Desktop/Format_1/hobokenhorse/hobokenhorse_all.csv
# File 943thepoint.csv copied to /Users/gayathri/Desktop/Format_1/943thepoint/943thepoint_all.csv
# File the-gazette-newspaper.csv copied to /Users/gayathri/Desktop/Format_1/the-gazette-newspaper/the-gazette-newspaper_all.csv
# File urbanagendamagazine.csv copied to /Users/gayathri/Desktop/Format_1/urbanagendamagazine/urbanagendamagazine_all.csv
# File njjewishnews.timesofisrael.csv copied to /Users/gayathri/Desktop/Format_1/njjewishnews.timesofisrael/njjewishnews.timesofisrael_all.csv
# File northjersey.csv copied to /Users/gayathri/Desktop/Format_1/northjersey/northjersey_all.csv
# File montclairdispatch.csv copied to /Users/gayathri/Desktop/Format_1/montclairdispatch/montclairdispatch_all.csv
# File dailyvoice.csv copied to /Users/gayathri/Desktop/Format_1/dailyvoice/dailyvoice_all.csv
# File recordonline.csv copied to /Users/gayathri/Desktop/Format_1/recordonline/recordonline_all.csv
# File unionnewsdaily.csv copied to /Users/gayathri/Desktop/Format_1/unionnewsdaily/unionnewsdaily_all.csv
# File wnyc.csv copied to /Users/gayathri/Desktop/Format_1/wnyc/wnyc_all.csv
# File wputimes.wordpress.csv copied to /Users/gayathri/Desktop/Format_1/wputimes.wordpress/wputimes.wordpress_all.csv
# File mycentraljersey.csv copied to /Users/gayathri/Desktop/Format_1/mycentraljersey/mycentraljersey_all.csv
# File essexnewsdaily.csv copied to /Users/gayathri/Desktop/Format_1/essexnewsdaily/essexnewsdaily_all.csv
# File tristatevoice.csv copied to /Users/gayathri/Desktop/Format_1/tristatevoice/tristatevoice_all.csv
# File southjerseybiz.csv copied to /Users/gayathri/Desktop/Format_1/southjerseybiz/southjerseybiz_all.csv
# File newjerseybuzz.csv copied to /Users/gayathri/Desktop/Format_1/newjerseybuzz/newjerseybuzz_all.csv
# File forward.csv copied to /Users/gayathri/Desktop/Format_1/forward/forward_all.csv
# File newsindiatimes.csv copied to /Users/gayathri/Desktop/Format_1/newsindiatimes/newsindiatimes_all.csv
# File brigantinenow.csv copied to /Users/gayathri/Desktop/Format_1/brigantinenow/brigantinenow_all.csv
# File theridernews.csv copied to /Users/gayathri/Desktop/Format_1/theridernews/theridernews_all.csv
# File princetonmagazine.csv copied to /Users/gayathri/Desktop/Format_1/princetonmagazine/princetonmagazine_all.csv
# File philadelphia.cbslocal.csv copied to /Users/gayathri/Desktop/Format_1/philadelphia.cbslocal/philadelphia.cbslocal_all.csv
# File southjerseyobserver.csv copied to /Users/gayathri/Desktop/Format_1/southjerseyobserver/southjerseyobserver_all.csv
# File pressofatlanticcity.csv copied to /Users/gayathri/Desktop/Format_1/pressofatlanticcity/pressofatlanticcity_all.csv
# File dirt-mag.csv copied to /Users/gayathri/Desktop/Format_1/dirt-mag/dirt-mag_all.csv
# File newstalk990.csv copied to /Users/gayathri/Desktop/Format_1/newstalk990/newstalk990_all.csv
# File thecoaster.csv copied to /Users/gayathri/Desktop/Format_1/thecoaster/thecoaster_all.csv
# File newjersey.news12.csv copied to /Users/gayathri/Desktop/Format_1/newjersey.news12/newjersey.news12_all.csv
# File telemundo47.csv copied to /Users/gayathri/Desktop/Format_1/telemundo47/telemundo47_all.csv
# File newjerseyglobe.csv copied to /Users/gayathri/Desktop/Format_1/newjerseyglobe/newjerseyglobe_all.csv
# File wsus1023.iheart.csv copied to /Users/gayathri/Desktop/Format_1/wsus1023.iheart/wsus1023.iheart_all.csv
# File ahherald.csv copied to /Users/gayathri/Desktop/Format_1/ahherald/ahherald_all.csv
# File tcnjsignal.csv copied to /Users/gayathri/Desktop/Format_1/tcnjsignal/tcnjsignal_all.csv
# File wvlt.csv copied to /Users/gayathri/Desktop/Format_1/wvlt/wvlt_all.csv
# File hammontongazette.csv copied to /Users/gayathri/Desktop/Format_1/hammontongazette/hammontongazette_all.csv
# File sojo1049.csv copied to /Users/gayathri/Desktop/Format_1/sojo1049/sojo1049_all.csv
# File savejersey.csv copied to /Users/gayathri/Desktop/Format_1/savejersey/savejersey_all.csv
# File latribunanj.csv copied to /Users/gayathri/Desktop/Format_1/latribunanj/latribunanj_all.csv
# File njbmagazine.csv copied to /Users/gayathri/Desktop/Format_1/njbmagazine/njbmagazine_all.csv
# File tygodnikplus.csv copied to /Users/gayathri/Desktop/Format_1/tygodnikplus/tygodnikplus_all.csv
# File fduequinox.wordpress.csv copied to /Users/gayathri/Desktop/Format_1/fduequinox.wordpress/fduequinox.wordpress_all.csv
# File brick.shorebeat.csv copied to /Users/gayathri/Desktop/Format_1/brick.shorebeat/brick.shorebeat_all.csv
# File newtownpress.csv copied to /Users/gayathri/Desktop/Format_1/newtownpress/newtownpress_all.csv
# File 6abc.csv copied to /Users/gayathri/Desktop/Format_1/6abc/6abc_all.csv
# File nepszava.csv copied to /Users/gayathri/Desktop/Format_1/nepszava/nepszava_all.csv
# File hellenicnews.csv copied to /Users/gayathri/Desktop/Format_1/hellenicnews/hellenicnews_all.csv
# File phl17.csv copied to /Users/gayathri/Desktop/Format_1/phl17/phl17_all.csv
# File anointedonline.csv copied to /Users/gayathri/Desktop/Format_1/anointedonline/anointedonline_all.csv
# File pocono967.csv copied to /Users/gayathri/Desktop/Format_1/pocono967/pocono967_all.csv
# File wwfm.csv copied to /Users/gayathri/Desktop/Format_1/wwfm/wwfm_all.csv
# File visionsnewspaper.csv copied to /Users/gayathri/Desktop/Format_1/visionsnewspaper/visionsnewspaper_all.csv
# File mycommunitysource.csv copied to /Users/gayathri/Desktop/Format_1/mycommunitysource/mycommunitysource_all.csv
# File wliw.csv copied to /Users/gayathri/Desktop/Format_1/wliw/wliw_all.csv
# File phillyvoice.csv copied to /Users/gayathri/Desktop/Format_1/phillyvoice/phillyvoice_all.csv
# File westmilfordmessenger.csv copied to /Users/gayathri/Desktop/Format_1/westmilfordmessenger/westmilfordmessenger_all.csv
# File jerseyshoreonline.csv copied to /Users/gayathri/Desktop/Format_1/jerseyshoreonline/jerseyshoreonline_all.csv
# File cccvoice.wordpress.csv copied to /Users/gayathri/Desktop/Format_1/cccvoice.wordpress/cccvoice.wordpress_all.csv
# File towntopics.csv copied to /Users/gayathri/Desktop/Format_1/towntopics/towntopics_all.csv
# File wbjb.csv copied to /Users/gayathri/Desktop/Format_1/wbjb/wbjb_all.csv
# File classicoldieswmid.csv copied to /Users/gayathri/Desktop/Format_1/classicoldieswmid/classicoldieswmid_all.csv
# File baristanet.csv copied to /Users/gayathri/Desktop/Format_1/baristanet/baristanet_all.csv
# File theobserver.csv copied to /Users/gayathri/Desktop/Format_1/theobserver/theobserver_all.csv
# File 951wayv.csv copied to /Users/gayathri/Desktop/Format_1/951wayv/951wayv_all.csv
# File medium.csv copied to /Users/gayathri/Desktop/Format_1/medium/medium_all.csv
# File 1077thebronc.csv copied to /Users/gayathri/Desktop/Format_1/1077thebronc/1077thebronc_all.csv
# File divyabhaskar.csv copied to /Users/gayathri/Desktop/Format_1/divyabhaskar/divyabhaskar_all.csv
# File rennamedia.csv copied to /Users/gayathri/Desktop/Format_1/rennamedia/rennamedia_all.csv
# File thepositivecommunity.csv copied to /Users/gayathri/Desktop/Format_1/thepositivecommunity/thepositivecommunity_all.csv
# File rahwayrising.csv copied to /Users/gayathri/Desktop/Format_1/rahwayrising/rahwayrising_all.csv
# File rcan.csv copied to /Users/gayathri/Desktop/Format_1/rcan/rcan_all.csv
# File roi-nj.csv copied to /Users/gayathri/Desktop/Format_1/roi-nj/roi-nj_all.csv
# File njpen.csv copied to /Users/gayathri/Desktop/Format_1/njpen/njpen_all.csv
# File wpgtalkradio.csv copied to /Users/gayathri/Desktop/Format_1/wpgtalkradio/wpgtalkradio_all.csv
# File nyc.csv copied to /Users/gayathri/Desktop/Format_1/nyc/nyc_all.csv
# File irishcentral.csv copied to /Users/gayathri/Desktop/Format_1/irishcentral/irishcentral_all.csv
# File ntd.csv copied to /Users/gayathri/Desktop/Format_1/ntd/ntd_all.csv
# File thecore.csv copied to /Users/gayathri/Desktop/Format_1/thecore/thecore_all.csv
# File indiaabroad.csv copied to /Users/gayathri/Desktop/Format_1/indiaabroad/indiaabroad_all.csv
# File radio.csv copied to /Users/gayathri/Desktop/Format_1/radio/radio_all.csv
# File townshipjournal.csv copied to /Users/gayathri/Desktop/Format_1/townshipjournal/townshipjournal_all.csv
# File shorelocalnews.csv copied to /Users/gayathri/Desktop/Format_1/shorelocalnews/shorelocalnews_all.csv
# File my9nj.csv copied to /Users/gayathri/Desktop/Format_1/my9nj/my9nj_all.csv
# File pinebarrenstribune.csv copied to /Users/gayathri/Desktop/Format_1/pinebarrenstribune/pinebarrenstribune_all.csv
# File wlvt.csv copied to /Users/gayathri/Desktop/Format_1/wlvt/wlvt_all.csv
# File lavocedinewyork.csv copied to /Users/gayathri/Desktop/Format_1/lavocedinewyork/lavocedinewyork_all.csv
# File ocsentinel.csv copied to /Users/gayathri/Desktop/Format_1/ocsentinel/ocsentinel_all.csv
# File downbeachbuzz.csv copied to /Users/gayathri/Desktop/Format_1/downbeachbuzz/downbeachbuzz_all.csv
# File montynews.csv copied to /Users/gayathri/Desktop/Format_1/montynews/montynews_all.csv
# File dailyprincetonian.csv copied to /Users/gayathri/Desktop/Format_1/dailyprincetonian/dailyprincetonian_all.csv
# File literock969.csv copied to /Users/gayathri/Desktop/Format_1/literock969/literock969_all.csv
# File thenjsentinel.csv copied to /Users/gayathri/Desktop/Format_1/thenjsentinel/thenjsentinel_all.csv
# File countywatchers.wordpress.csv copied to /Users/gayathri/Desktop/Format_1/countywatchers.wordpress/countywatchers.wordpress_all.csv
# File theyeshivaworld.csv copied to /Users/gayathri/Desktop/Format_1/theyeshivaworld/theyeshivaworld_all.csv
# File am970theanswer.csv copied to /Users/gayathri/Desktop/Format_1/am970theanswer/am970theanswer_all.csv
# File wsou.csv copied to /Users/gayathri/Desktop/Format_1/wsou/wsou_all.csv
# File njrevolutionradio.csv copied to /Users/gayathri/Desktop/Format_1/njrevolutionradio/njrevolutionradio_all.csv
# File tapinto.csv copied to /Users/gayathri/Desktop/Format_1/tapinto/tapinto_all.csv
# File law.csv copied to /Users/gayathri/Desktop/Format_1/law/law_all.csv
# File thedrewacorn.csv copied to /Users/gayathri/Desktop/Format_1/thedrewacorn/thedrewacorn_all.csv
# File courierpostonline.csv copied to /Users/gayathri/Desktop/Format_1/courierpostonline/courierpostonline_all.csv
# File eccobserverdotcom.wordpress.csv copied to /Users/gayathri/Desktop/Format_1/eccobserverdotcom.wordpress/eccobserverdotcom.wordpress_all.csv
# File spartaindependent.csv copied to /Users/gayathri/Desktop/Format_1/spartaindependent/spartaindependent_all.csv
# File 1057thehawk.csv copied to /Users/gayathri/Desktop/Format_1/1057thehawk/1057thehawk_all.csv
# File princetoninfo.csv copied to /Users/gayathri/Desktop/Format_1/princetoninfo/princetoninfo_all.csv
# File gujaratdarpan.csv copied to /Users/gayathri/Desktop/Format_1/gujaratdarpan/gujaratdarpan_all.csv
# File posteaglenewspaper.csv copied to /Users/gayathri/Desktop/Format_1/posteaglenewspaper/posteaglenewspaper_all.csv

# %%
## 987thecoast has no data in it and hence no folder formed

# %%
### Let us count the number of different sub-bart files present for each domain

import os
import pandas as pd

def get_unique_bart_labels(folder_path):
    data = []
    for root, dirs, files in os.walk(folder_path):
        unique_labels = set()
        domain_name = os.path.basename(root)

        for file_name in files:
            if file_name.endswith(".csv"):
                bart_label = os.path.splitext(file_name)[0].replace(domain_name + "_", "")
                unique_labels.add(bart_label)

        data.append({'domain_name': domain_name, 'unique_bart_labels': len(unique_labels), 'bart_labels': ', '.join(unique_labels)})

    return data

def write_bart_labels_to_csv(folder_path, output_csv):
    data = get_unique_bart_labels(folder_path)
    df = pd.DataFrame(data)
    df.to_csv(output_csv, index=False)

folder_path = '/Users/gayathri/Desktop/Format_1'  
output_csv = '/Users/gayathri/Desktop/domain_label_details.csv'  
write_bart_labels_to_csv(folder_path, output_csv)

# %%
import os
import pandas as pd
import numpy as np
import folium

def process_csv_file(csv_file, color):


        for index, row in df.iterrows():
            location = row["gpe"]
            latitude = row["gpe_latitude"]
            longitude = row["gpe_longitude"]
            count = row["gpe_sum"]
            log_count = row["gpe_sum_log"]
            bart_label = row["bart_label"]
            popup_text = f"Location: {location}\nCount: {count}\nLabel: {bart_label}"
            marker_size = get_marker_size(log_count)
            folium.CircleMarker(
                [latitude, longitude],
                popup=popup_text,
                radius=marker_size,
                color=color,
                fill=True,
                fill_color=color
            ).add_to(mymap)

        folder_path = os.path.dirname(csv_file)
        filename = os.path.splitext(os.path.basename(csv_file))[0] + ".html"
        output_file = os.path.join(folder_path, filename)
        mymap.save(output_file)

def process_subfolders(folder_path, color_palette):
    color_index = 0
    for root, dirs, files in os.walk(folder_path):
        for dir_name in dirs:
            subfolder_path = os.path.join(root, dir_name)
            for filename in os.listdir(subfolder_path):
                if filename.endswith(".csv"):
                    csv_file = os.path.join(subfolder_path, filename)
                    color = color_palette[color_index % len(color_palette)]
                    process_csv_file(csv_file, color)
                    color_index += 1

# Example usage:
folder_path = "/Users/gayathri/Desktop/Format_1"
color_palette = ['#e6194b', '#3cb44b', '#194fff', '#873ec7', '#de6109', 
                 '#911eb4', '#f7890a', '#f032e6', '#ce7e00', '#6a329f']

process_subfolders(folder_path, color_palette)
# Out:
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/1801769464.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor

# %%
import os
import pandas as pd
import numpy as np
import folium

def generate_map(csv_file):
    df = pd.read_csv(csv_file)
    # Filter out rows where 'gpe' is in the specified exclusion list
    exclusion_list = ['New Jersey', 'NJ', 'The Garden State', 'Nj', 'New Jerseyans',' US','U.S', 'U.S.', 'USA', 'U.S.A', 'United States', 'United States of America', 'The United States']
    df = df[~df['gpe'].isin(exclusion_list)]
    
    # Proceed if df is not empty after filtering
    if not df.empty:
        df['gpe_sum_log'] = np.log(df['gpe_sum']) / np.log(np.e)  
        map_zoom = 10
        max_occurrences_row = df.loc[df['gpe_sum'].idxmax()]
        highest_occurrences_latitude = max_occurrences_row['gpe_latitude']
        highest_occurrences_longitude = max_occurrences_row['gpe_longitude']
        highest_occurrence = [highest_occurrences_latitude, highest_occurrences_longitude]
        mymap = folium.Map(location=highest_occurrence, zoom_start=map_zoom)
        max_count = df["gpe_sum_log"].max()

        def get_marker_size(log_count):
            scale_factor = 10  
            return 5 + (log_count / max_count) * scale_factor

        colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', 
                  '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080']

        bart_label_color_map = dict(zip(df['bart_label'].unique(), colors))

        for index, row in df.iterrows():
            location = row["gpe"]
            latitude = row["gpe_latitude"]
            longitude = row["gpe_longitude"]
            count = row["gpe_sum"]
            log_count = row["gpe_sum_log"]
            bart_label = row["bart_label"]
            popup_text = f"Location: {location}\nCount: {count}\nLabel: {bart_label}"
            marker_size = get_marker_size(log_count)
            color = bart_label_color_map.get(bart_label, "#FF0000")  
            folium.CircleMarker(
                [latitude, longitude],
                popup=popup_text,
                radius=marker_size,
                color=color,
                fill=True,
                fill_color=color
            ).add_to(mymap)

        legend_html = """
             <div style="position: fixed; 
                    bottom: 50px; left: 50px; width: 200px; min-height: 150px; 
                    border:2px solid grey; z-index:9999; font-size:14px;
                    background-color: white; padding: 5px;
                        ">
             &nbsp; <strong>Legend</strong> <br>
             """
        for label, color in bart_label_color_map.items():
            legend_html += f"&nbsp; <i class='fa fa-circle' style='color:{color}'></i> {label}<br>"
        legend_html += """
             </div>
             """
        mymap.get_root().html.add_child(folium.Element(legend_html))
        filename = os.path.splitext(os.path.basename(csv_file))[0] + ".html"
        output_path = os.path.join(os.path.dirname(csv_file), filename)
        mymap.save(output_path)

def generate_maps_in_subfolders(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for dir_name in dirs:
            subfolder_path = os.path.join(root, dir_name)
            csv_files = [f for f in os.listdir(subfolder_path) if f.endswith('.csv') and '_all' in f]
            for csv_file in csv_files:
                csv_file_path = os.path.join(subfolder_path, csv_file)
                generate_map(csv_file_path)

# Example usage:
folder_path = "/Users/gayathri/Desktop/Format_1"
generate_maps_in_subfolders(folder_path)
# Out:
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor
# /var/folders/rz/xf93n76s47j1cw7f6v661b040000gn/T/ipykernel_53673/4080590389.py:25: RuntimeWarning: invalid value encountered in scalar divide
#   return 5 + (log_count / max_count) * scale_factor

# %%
import pandas as pd

def generate_domain_bart_dict(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)
    
    # Initialize an empty dictionary to store domain names and corresponding BART labels
    domain_bart_dict = {}
    
    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        domain_name = row['domain_name']
        bart_labels = str(row['bart_labels'])  # Convert bart_labels to string
        
        # If domain_name already exists in the dictionary, append the new BART label
        if domain_name in domain_bart_dict:
            domain_bart_dict[domain_name].append(bart_labels)
        # If domain_name is new, create a new entry with the BART label
        else:
            domain_bart_dict[domain_name] = [bart_labels]
    
    # Convert the dictionary values to strings
    for domain, labels in domain_bart_dict.items():
        domain_bart_dict[domain] = ', '.join(labels)
    
    return domain_bart_dict

# Example usage:
csv_file = '/Users/gayathri/Desktop/domain_label_details.csv'
domain_bart_dict = generate_domain_bart_dict(csv_file)
print(domain_bart_dict)
# Out:
# {'Format_1': 'nan', 'thecoaster': 'business, education, all, world, environment, politics, automobile, crime, health, sports', '1057thehawk': 'business, education, all, world, environment, politics, automobile, crime, health, sports', 'telemundo47': 'all, politics', 'westmilfordmessenger': 'business, education, all, environment, world, politics, crime, health, sports', 'tristatevoice': 'all, world, politics, sports', 'wlvt': 'business, all', '943thepoint': 'business, education, miscellaneous, world, environment, all, politics, automobile, crime, health, sports', 'thedrewacorn': 'business, education, all, world, environment, politics, health, sports', 'townshipjournal': 'business, education, all, world, environment, politics, crime, health, sports', 'princetoninfo': 'business, all', 'lavocedinewyork': 'business, education, all, world, environment, politics, crime, health, sports', 'northjersey': 'business, education, miscellaneous, environment, world, all, politics, automobile, crime, health, sports', '951wayv': 'business, all, world, politics, crime, health', '6abc': 'business, education, miscellaneous, world, environment, all, politics, automobile, crime, health, sports', 'radio': 'business, education, all, world, politics, sports', 'visionsnewspaper': 'business, all', 'civicstory': 'business, all, politics', 'tygodnikplus': 'business, all', 'thepakistaninewspaper': 'all, world', 'irishcentral': 'business, all, environment, world, miscellaneous, politics, crime, health, sports', 'classicoldieswmid': 'business, all, world, politics, crime, health, sports', 'wwfm': 'business, education, all, world, environment, politics, crime, health', 'newtownpress': 'business, education, all, world, environment, politics, crime, health, sports', 'ahherald': 'business, education, all, world, environment, politics, crime, health, sports', 'rahwayrising': 'business, all, environment, world, politics, crime', 'mycentraljersey': 'business, education, miscellaneous, environment, all, world, politics, automobile, crime, health, sports', 'phl17': 'business, education, all, world, politics, automobile, crime, health, sports', 'njjewishnews.timesofisrael': 'business, education, miscellaneous, world, all, politics, health', 'rcan': 'all, politics', 'dailyprincetonian': 'business, education, all, world, environment, politics, crime, health, sports', 'ocsentinel': 'all, world', 'dailyvoice': 'business, education, all, environment, world, politics, automobile, crime, health, sports', 'urbanagendamagazine': 'business, education, all, environment, world, health, sports', 'law': 'business, education, all, world, environment, politics', 'thepositivecommunity': 'business, education, all, world, politics, health, sports', 'wpgtalkradio': 'business, education, all, world, environment, politics, automobile, crime, health, sports', '1077thebronc': 'business, all', 'theyeshivaworld': 'business, education, all, environment, world, politics, automobile, crime, health', 'courierpostonline': 'business, education, all, world, miscellaneous, environment, politics, automobile, crime, health, sports', 'medium': 'business, education, all, politics, crime, health, sports', 'posteaglenewspaper': 'business, education, all, world, environment, politics, health, sports', 'wvlt': 'business, all, world', 'wurdradio': 'business, all', 'fduequinox.wordpress': 'business, education, all, environment, world, politics, crime, health, sports', 'wsus1023.iheart': 'business, education, all, world, environment, politics, crime, health, sports', 'hobokenhorse': 'business, all, world, environment, politics, automobile, crime', 'jerseyshoreonline': 'business, education, miscellaneous, all, environment, world, politics, automobile, crime, health, sports', 'my9nj': 'business, all, environment, politics, crime, health', 'divyabhaskar': 'business, all, environment', 'anointedonline': 'business, all', 'wputimes.wordpress': 'business, education, all, world, environment, politics, crime, health, spor ...
